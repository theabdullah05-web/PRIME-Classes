# %%
from scipy.stats import binom

# %%
n=5
k=3
p=0.5
prob=binom.pmf(k,n,p)
print(prob)
# Out:
# 0.31249999999999983

# %%
import numpy as np
import matplotlib.pyplot as plt

values=np.random.uniform(0,10,1_000)

plt.hist(values,bins=10,density=True,alpha=0.3)
plt.title("Continous Distribution between 0 and 10")
plt.xlabel("x")
plt.ylabel("probability distribution")
plt.grid(True)
