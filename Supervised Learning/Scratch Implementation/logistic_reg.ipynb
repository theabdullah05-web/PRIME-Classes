# %%
import numpy as np

# %%
#Logistic Regression
class LogisticRegression():
    def __init__(self,learning_rate=0.1,n_iter=1000):
        self.bias=None
        self.weights=None
        self.lr=learning_rate
        self.n_iter=n_iter
