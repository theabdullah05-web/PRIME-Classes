# %%
import numpy as np

# %%
#Linear Regression
class LinearRegression:

    def __init__(self,learning_rate=0.01,n_iter=1000):
        self.bias=None
        self.weights=None
        self.lr=learning_rate
        self.n_iter=n_iter
    def fit(self,X,y):
        m,n=X.shape
        #Step1 - Initialize params
        self.bias=0
        self.weights=np.zeros(n)

        #Greadient Descent
        for i in range(self.n_iter):
            #Step - Calculate y_pred
            y_pred=self.bias+np.dot(X,self.weights)

            #Step3 - Calculate gradients
            db=(1/m)*np.sum(y_pred-y)
            dw=(1/m)*np.dot(X.T,(y_pred-y))

            #Step4 - Apply Convergence Thoerum - Params Update
            self.bias-=self.lr*db
            self.weights-=self.lr*dw

    def predict(self,X):
        y_pred=self.bias+np.dot(X,self.weights)
        return y_pred

# %%
X=np.array([[1],[2],[3],[4],[5]])
y=np.array([2,4,6,8,10])
model=LinearRegression()
model.fit(X,y)
y_pred=model.predict(X)
print(y_pred)
# Out:
# [2.06850809 4.04226297 6.01601785 7.98977273 9.96352761]

# %%
#Linear Regression with OLS
class LinearRegressionOLS:
    def __init__(self):
        self.bias=0
        self.weights=0
    def fit(self,X,y):
        m,n=X.shape
        X_b=np.c_[np.ones((m,1))]
        theta=np.linalg.inv(X_b.T@X_b)@X_b.T@y
        self.bias=theta[0]
        self.weights=theta[1:]
    def predict(self,X):
        y_pred=self.bias+np.dot(X,self.weights)
        return y_pred

# %%
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 6, 8, 10])
model = LinearRegressionOLS()
model.fit(X, y)
X_b = np.c_[np.ones((X.shape[0], 1)), X]
theta = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y
model.bias = theta[0]
model.weights = theta[1:]
y_pred = model.predict(X)
print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 5
#       3 model = LinearRegressionOLS()
#       4 model.fit(X, y)
# ----> 5 y_pred = model.predict(X)
#       6 print(y_pred)
#
# Cell In[15], line 13, in LinearRegressionOLS.predict(self, X)
#      12 def predict(self,X):
# ---> 13     y_pred=self.bias+np.dot(X,self.weights)
#      14     return y_pred
#
# ValueError: shapes (5,1) and (0,) not aligned: 1 (dim 1) != 0 (dim 0)
