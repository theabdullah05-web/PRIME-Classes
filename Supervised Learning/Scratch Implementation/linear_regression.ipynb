# %%
import numpy as np

# %%
#Linear Regression
class LinearRegression:

    def __init__(self,learning_rate=0.01,n_iter=1000):
        self.bias=None
        self.weights=None
        self.lr=learning_rate
        self.n_iter=n_iter
    def fit(self,X,y):
        m,n=X.shape()
        #Step1 - Initialize params
        self.bias=0
        self.weights=np.zeros(n)

        #Greadient Descent
        for i in range(self.n_iter):
            #Step - Calculate y_pred
            y_pred=self.bias+np.dot(X,self.weights)

            #Step3 - Calculate gradients
            db=(1/m)*np.sum(y_pred-y)
            dw=(1/m)*np.dot(X.T,(y_pred-y))

            #Step4 - Apply Convergence Thoerum - Params Update
            self.bias-=self.lr*db
            self.weights-=self.lr*dw

    def predict(self,X):
        y_pred=self.bias+np.dot(X,self.weights)
        return y_pred

# %%
X=np.array([[1],[2],[3],[4],[5]])
y=np.array([2,4,6,8,10])
model=LinearRegression()
model.fit(X,y)
y_pred=model.predict(X)
print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 y=np.array([2,4,6,8,10])
#       3 model=LinearRegression()
# ----> 4 model.fit(X,y)
#       5 y_pred=model.predict(X)
#       6 print(y_pred)
#
# Cell In[5], line 10, in LinearRegression.fit(self, X, y)
#       9 def fit(self,X,y):
# ---> 10     m,n=X.shape()
#      11     #Step1 - Initialize params
#      12     self.bias=0
#
# TypeError: 'tuple' object is not callable
